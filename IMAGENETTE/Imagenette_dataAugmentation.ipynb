# %%
import numpy as np 
import os
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Data Load and Analysis
# ### Imagenette dataset is available on https://github.com/fastai/imagenette .
#
#  `print(imagenette_info)` gives following Information regarding the dataset:
#
# *   `image.shape` -> (shape=(None, None, 3) we recognize that the images contained in the dataset have different sizes
# *   By num_classes=10 we know that all images belong to 10 classes, or categories
# *   total_num_examples=13394 indicates the number of images
# *   Also, the images are already divided into "train" and "validation" and contain 9469 and 3925 images, respectively.

# %%
# reference :- https://www.tensorflow.org/datasets/overview
batch_size = 64
imagenette_builder = tfds.builder("imagenette/full-size-v2")
imagenette_info = imagenette_builder.info
print(imagenette_info)

imagenette_builder.download_and_prepare()
datasets = imagenette_builder.as_dataset(as_supervised=True)
(train_datasets,test_datasets)=imagenette_builder.as_dataset(split=['train', 'validation'],as_supervised=True, shuffle_files=True)
train_examples = imagenette_info.splits['train'].num_examples
validation_examples = imagenette_info.splits['validation'].num_examples


ds= train_datasets.take(4)  # Only take a few example
for image, label in ds:  # example is (image, label)
  print(image.shape, tfds.as_numpy(label))


print("Train")
print(train_examples)
tfds.show_examples(train_datasets, imagenette_builder.info)

print("Test")
print(validation_examples)
tfds.show_examples(test_datasets, imagenette_builder.info)
# Out:
# tfds.core.DatasetInfo(
#     name='imagenette',
#     version=0.1.0,
#     description='Imagenette is a subset of 10 easily classified classes from the Imagenet
# dataset. It was originally prepared by Jeremy Howard of FastAI. The objective
# behind putting together a small version of the Imagenet dataset was mainly
# because running new ideas/algorithms/experiments on the whole Imagenet take a
# lot of time.
#
# This version of the dataset allows researchers/practitioners to quickly try out
# ideas and share with others. The dataset comes in three variants:
#
#   * Full size
#   * 320 px
#   * 160 px
#
# Note: The v2 config correspond to the new 70/30 train/valid split (released
# in Dec 6 2019).',
#     homepage='https://github.com/fastai/imagenette',
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     total_num_examples=13394,
#     splits={
#         'train': 9469,
#         'validation': 3925,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@misc{imagenette,
#       author    = "Jeremy Howard",
#       title     = "imagenette",
#       url       = "https://github.com/fastai/imagenette/"
#     }""",
#     redistribution_info=,
# )
#
# (375, 500, 3) 7
# (960, 1280, 3) 7
# (332, 500, 3) 4
# (500, 333, 3) 1
# Train
# 9469
# Test
# 3925

# %%
tfds.as_dataframe(train_datasets.take(4), imagenette_builder.info)
# Out:
#                                                image  label
# 0  [[[149, 152, 157], [145, 146, 151], [149, 148,...      7
# 1  [[[255, 255, 255], [253, 253, 253], [255, 255,...      6
# 2  [[[146, 156, 157], [144, 159, 156], [144, 159,...      6
# 3  [[[235, 235, 235], [240, 240, 240], [245, 245,...      5

# %%
info = imagenette_builder.info
print(info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })

# %% [markdown]
# Finally, there are 10 classes to which the images are assigned.  `print(info.features['label'].names)` goves this information.
# Look into the images and determine the class label .
#
# https://github.com/fastai/imagenette shows Imagenet classes are (tench, English springer, cassette player, chain saw, church, French horn, garbage truck, gas pump, golf ball, parachute).

# %%
print(info.features["label"].num_classes)
print(info.features["label"].names)
print(info.features["label"].int2str(7))  # Human readable version (7 -> 'n03425413'->'gas pump')
print(info.features["label"].str2int('n03425413'))
class_labels = ['tench', 'English springer', 'cassette player', 'chain saw', 'church', 'French horn', 
                  'garbage truck', 'gas pump', 'golf ball', 'parachute']
# Out:
# 10
# ['n01440764', 'n02102040', 'n02979186', 'n03000684', 'n03028079', 'n03394916', 'n03417042', 'n03425413', 'n03445777', 'n03888257']
# n03425413
# 7

# %%
print(info.features.shape)
print(info.features.dtype)
print(info.features['image'].shape)
print(info.features['image'].dtype)
# Out:
# {'image': (None, None, 3), 'label': ()}
# {'image': tf.uint8, 'label': tf.int64}
# (None, None, 3)
# <dtype: 'uint8'>

# %%
print(info.splits)
print(list(info.splits.keys()))
# Out:
# {'train': <tfds.core.SplitInfo num_examples=9469>, 'validation': <tfds.core.SplitInfo num_examples=3925>}
# ['train', 'validation']

# %% [markdown]
# # Preprocessing steps
#
# 1.   Resize all the images (128,128, 3)
# 2.   Normalize pixel values of each image so that they are all in a   range between 0 and 1. Normally the value of a pixel is between 0 and 255 (RGB color values), but the neural networks prefer to calculate with values between 0 and 1, so we will simply divide each pixel value by 255.

# %%
size_image = 128
resize_and_rescale = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Resizing(size_image, size_image,crop_to_aspect_ratio=True),
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
])

# %%
train_datasets = train_datasets.map(
  lambda image,label: (resize_and_rescale(image, training=True),label))

# %%
test_datasets = test_datasets.map(
  lambda image, label: (resize_and_rescale(image, training=False), label))

# %%
for img, label in train_datasets.take(5):
  print(img.shape,label)
# Out:
# (128, 128, 3) tf.Tensor(0, shape=(), dtype=int64)
# (128, 128, 3) tf.Tensor(2, shape=(), dtype=int64)
# (128, 128, 3) tf.Tensor(5, shape=(), dtype=int64)
# (128, 128, 3) tf.Tensor(0, shape=(), dtype=int64)
# (128, 128, 3) tf.Tensor(3, shape=(), dtype=int64)

# %%
def plot_images(data, size=(20,20)):
  plt.figure(figsize=size)
  for i in range(25):
    for img, label in data.take(i+1):
      plt.subplot(5, 5, i + 1)
      plt.xticks([])
      plt.yticks([])
      plt.grid(True)
      plt.imshow(img, cmap=plt.cm.binary)
      plt.title(class_labels[label])
      plt.ylabel(img.shape)
  plt.show()

# %%
plot_images(train_datasets)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# define data preparation
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
train_datasets = train_datasets.map(
  lambda image,label: (data_augmentation(image,training=True),label))

# %%
plot_images(train_datasets)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %% [markdown]
# # Model

# %%
# patient early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3),padding='same', activation=tf.keras.layers.ReLU(),input_shape=(128,128,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation=tf.keras.layers.ReLU()),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation=tf.keras.layers.ReLU()),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation=tf.keras.layers.ReLU()),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64,activation=tf.keras.layers.ReLU()),    
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10,activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      896
#
#  batch_normalization_5 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_6 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_7 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_8 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 64)                262208
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 357,258
# Trainable params: 356,682
# Non-trainable params: 576
# _________________________________________________________________

# %%
train_batch = train_datasets.batch(128)

test_batch = test_datasets.batch(128)

# %%
for img, label in train_batch.take(5):
  print(img.shape,label)
# Out:
# (128, 128, 128, 3) tf.Tensor(
# [9 3 6 3 3 6 7 3 7 5 2 0 3 6 3 0 4 9 0 2 4 7 5 0 3 8 3 0 6 4 8 5 9 1 6 9 2
#  5 4 4 6 8 0 0 1 6 7 6 2 5 0 3 0 2 4 9 4 8 8 3 5 8 7 7 5 0 6 0 3 7 4 9 9 4
#  7 9 8 6 3 9 6 2 2 4 6 6 6 2 1 6 4 4 2 5 7 6 9 3 1 4 5 9 1 5 6 9 1 3 7 5 0
#  2 9 7 3 5 4 7 1 0 7 0 4 9 9 3 0 0], shape=(128,), dtype=int64)
# (128, 128, 128, 3) tf.Tensor(
# [4 7 6 6 8 2 7 0 5 0 8 6 1 6 3 3 8 5 5 6 6 2 7 7 0 3 4 3 9 3 8 9 2 6 4 0 8
#  1 2 7 4 0 6 2 3 9 8 8 2 6 7 3 4 5 3 3 3 4 4 3 2 7 4 5 0 3 2 8 2 0 1 0 1 1
#  3 8 3 2 7 1 9 3 3 6 0 2 5 2 9 9 4 5 7 5 2 1 7 7 4 1 5 2 4 7 8 3 6 3 8 8 8
#  5 6 5 0 5 3 8 9 0 9 1 9 7 2 7 7 2], shape=(128,), dtype=int64)
# (128, 128, 128, 3) tf.Tensor(
# [4 7 3 0 9 6 0 2 2 1 7 9 0 8 6 2 0 4 1 2 8 2 4 6 8 2 9 9 5 0 0 7 5 5 9 3 3
#  4 0 3 8 3 7 9 8 8 9 8 4 0 8 4 0 2 7 3 6 2 0 9 2 4 5 4 8 1 6 2 8 6 9 1 5 8
#  0 8 1 6 9 7 4 7 8 5 6 3 4 6 4 4 9 7 0 4 9 5 1 7 3 6 1 0 8 6 4 0 5 6 3 8 1
#  6 0 3 2 6 6 8 1 6 0 3 1 5 9 5 0 5], shape=(128,), dtype=int64)
# (128, 128, 128, 3) tf.Tensor(
# [3 0 1 7 1 2 6 8 0 9 8 2 5 8 5 0 8 3 5 6 5 7 0 1 3 0 6 3 1 2 3 4 7 7 4 7 7
#  1 8 2 1 5 0 0 6 6 0 1 2 8 0 0 1 8 4 4 3 6 9 8 4 8 0 8 5 8 7 4 2 7 0 2 3 2
#  5 5 0 1 2 6 5 6 6 0 2 8 7 4 8 4 3 0 9 8 4 5 4 3 9 5 4 2 3 6 9 2 9 4 8 8 1
#  3 9 0 5 8 9 7 6 5 8 8 8 2 1 7 7 2], shape=(128,), dtype=int64)
# (128, 128, 128, 3) tf.Tensor(
# [3 0 1 0 1 7 8 7 4 2 5 4 5 0 4 3 8 6 1 7 9 6 9 7 1 3 1 0 2 2 5 0 6 2 0 1 0
#  4 3 8 9 1 8 8 9 2 8 2 0 8 9 0 3 2 4 4 3 4 3 7 5 7 8 5 4 2 4 1 5 8 2 6 7 2
#  9 4 7 2 4 1 1 5 3 5 9 9 1 8 6 0 9 5 5 7 5 6 6 1 2 2 7 8 5 3 1 2 9 9 2 4 6
#  8 8 7 7 3 3 6 6 5 9 5 7 2 8 6 0 5], shape=(128,), dtype=int64)

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
history = model.fit(train_batch,epochs=2000,validation_data=test_batch,callbacks=[es])
# Out:
# Epoch 1/2000
# 74/74 [==============================] - 30s 384ms/step - loss: 2.3507 - accuracy: 0.2378 - val_loss: 2.9683 - val_accuracy: 0.0994
# Epoch 2/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 1.9755 - accuracy: 0.3361 - val_loss: 3.8254 - val_accuracy: 0.0994
# Epoch 3/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 1.8054 - accuracy: 0.3883 - val_loss: 4.4989 - val_accuracy: 0.0991
# Epoch 4/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 1.7007 - accuracy: 0.4265 - val_loss: 4.2024 - val_accuracy: 0.1088
# Epoch 5/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 1.6093 - accuracy: 0.4514 - val_loss: 3.5690 - val_accuracy: 0.1483
# Epoch 6/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 1.5528 - accuracy: 0.4734 - val_loss: 2.7362 - val_accuracy: 0.2392
# Epoch 7/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 1.4964 - accuracy: 0.4979 - val_loss: 1.9157 - val_accuracy: 0.3758
# Epoch 8/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 1.4445 - accuracy: 0.5196 - val_loss: 1.6030 - val_accuracy: 0.4680
# Epoch 9/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 1.4082 - accuracy: 0.5266 - val_loss: 1.4701 - val_accuracy: 0.5065
# Epoch 10/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 1.3682 - accuracy: 0.5357 - val_loss: 1.4252 - val_accuracy: 0.5220
# Epoch 11/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 1.3329 - accuracy: 0.5496 - val_loss: 1.4002 - val_accuracy: 0.5243
# Epoch 12/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 1.3141 - accuracy: 0.5602 - val_loss: 1.4403 - val_accuracy: 0.5185
# Epoch 13/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 1.2933 - accuracy: 0.5650 - val_loss: 1.3788 - val_accuracy: 0.5378
# Epoch 14/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 1.2610 - accuracy: 0.5785 - val_loss: 1.3717 - val_accuracy: 0.5447
# Epoch 15/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 1.2479 - accuracy: 0.5851 - val_loss: 1.3402 - val_accuracy: 0.5613
# Epoch 16/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 1.2262 - accuracy: 0.5893 - val_loss: 1.4052 - val_accuracy: 0.5330
# Epoch 17/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 1.2177 - accuracy: 0.5957 - val_loss: 1.3265 - val_accuracy: 0.5620
# Epoch 18/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 1.1880 - accuracy: 0.6047 - val_loss: 1.3108 - val_accuracy: 0.5669
# Epoch 19/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 1.1806 - accuracy: 0.6071 - val_loss: 1.3523 - val_accuracy: 0.5564
# Epoch 20/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 1.1573 - accuracy: 0.6166 - val_loss: 1.3203 - val_accuracy: 0.5682
# Epoch 21/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 1.1492 - accuracy: 0.6210 - val_loss: 1.2867 - val_accuracy: 0.5806
# Epoch 22/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 1.1287 - accuracy: 0.6230 - val_loss: 1.3103 - val_accuracy: 0.5661
# Epoch 23/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 1.1298 - accuracy: 0.6272 - val_loss: 1.2593 - val_accuracy: 0.5865
# Epoch 24/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 1.1075 - accuracy: 0.6309 - val_loss: 1.2750 - val_accuracy: 0.5804
# Epoch 25/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 1.1018 - accuracy: 0.6341 - val_loss: 1.2815 - val_accuracy: 0.5817
# Epoch 26/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 1.0840 - accuracy: 0.6422 - val_loss: 1.2685 - val_accuracy: 0.5811
# Epoch 27/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 1.0734 - accuracy: 0.6414 - val_loss: 1.2351 - val_accuracy: 0.5980
# Epoch 28/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 1.0653 - accuracy: 0.6426 - val_loss: 1.2580 - val_accuracy: 0.5865
# Epoch 29/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 1.0592 - accuracy: 0.6493 - val_loss: 1.2153 - val_accuracy: 0.6028
# Epoch 30/2000
# 74/74 [==============================] - 28s 379ms/step - loss: 1.0443 - accuracy: 0.6523 - val_loss: 1.2169 - val_accuracy: 0.6066
# Epoch 31/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 1.0370 - accuracy: 0.6554 - val_loss: 1.3064 - val_accuracy: 0.5638
# Epoch 32/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 1.0318 - accuracy: 0.6557 - val_loss: 1.2425 - val_accuracy: 0.5982
# Epoch 33/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 1.0190 - accuracy: 0.6633 - val_loss: 1.2188 - val_accuracy: 0.6059
# Epoch 34/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 1.0104 - accuracy: 0.6656 - val_loss: 1.2122 - val_accuracy: 0.6056
# Epoch 35/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 1.0066 - accuracy: 0.6707 - val_loss: 1.2587 - val_accuracy: 0.5862
# Epoch 36/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.9987 - accuracy: 0.6708 - val_loss: 1.2888 - val_accuracy: 0.5799
# Epoch 37/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 0.9885 - accuracy: 0.6720 - val_loss: 1.1890 - val_accuracy: 0.6138
# Epoch 38/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.9755 - accuracy: 0.6788 - val_loss: 1.2272 - val_accuracy: 0.5972
# Epoch 39/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.9653 - accuracy: 0.6854 - val_loss: 1.1768 - val_accuracy: 0.6153
# Epoch 40/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.9797 - accuracy: 0.6747 - val_loss: 1.1697 - val_accuracy: 0.6171
# Epoch 41/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.9623 - accuracy: 0.6820 - val_loss: 1.2049 - val_accuracy: 0.6082
# Epoch 42/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.9488 - accuracy: 0.6895 - val_loss: 1.1553 - val_accuracy: 0.6262
# Epoch 43/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.9488 - accuracy: 0.6842 - val_loss: 1.2130 - val_accuracy: 0.5992
# Epoch 44/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 0.9471 - accuracy: 0.6905 - val_loss: 1.1253 - val_accuracy: 0.6387
# Epoch 45/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.9280 - accuracy: 0.6966 - val_loss: 1.1772 - val_accuracy: 0.6186
# Epoch 46/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.9264 - accuracy: 0.6934 - val_loss: 1.1397 - val_accuracy: 0.6321
# Epoch 47/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.9187 - accuracy: 0.6966 - val_loss: 1.1759 - val_accuracy: 0.6186
# Epoch 48/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.9096 - accuracy: 0.6968 - val_loss: 1.1964 - val_accuracy: 0.6135
# Epoch 49/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.9084 - accuracy: 0.6983 - val_loss: 1.1763 - val_accuracy: 0.6214
# Epoch 50/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.9039 - accuracy: 0.7024 - val_loss: 1.1837 - val_accuracy: 0.6204
# Epoch 51/2000
# 74/74 [==============================] - 29s 391ms/step - loss: 0.8922 - accuracy: 0.7083 - val_loss: 1.1254 - val_accuracy: 0.6403
# Epoch 52/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.8971 - accuracy: 0.7057 - val_loss: 1.1179 - val_accuracy: 0.6405
# Epoch 53/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8902 - accuracy: 0.7098 - val_loss: 1.1216 - val_accuracy: 0.6369
# Epoch 54/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.8809 - accuracy: 0.7093 - val_loss: 1.1301 - val_accuracy: 0.6380
# Epoch 55/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8762 - accuracy: 0.7083 - val_loss: 1.1375 - val_accuracy: 0.6367
# Epoch 56/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8737 - accuracy: 0.7124 - val_loss: 1.2154 - val_accuracy: 0.6132
# Epoch 57/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8659 - accuracy: 0.7157 - val_loss: 1.1922 - val_accuracy: 0.6173
# Epoch 58/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.8566 - accuracy: 0.7163 - val_loss: 1.2155 - val_accuracy: 0.6132
# Epoch 59/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 0.8559 - accuracy: 0.7182 - val_loss: 1.1611 - val_accuracy: 0.6280
# Epoch 60/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8477 - accuracy: 0.7204 - val_loss: 1.1053 - val_accuracy: 0.6405
# Epoch 61/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.8494 - accuracy: 0.7175 - val_loss: 1.1144 - val_accuracy: 0.6385
# Epoch 62/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8389 - accuracy: 0.7254 - val_loss: 1.1712 - val_accuracy: 0.6275
# Epoch 63/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.8361 - accuracy: 0.7266 - val_loss: 1.1214 - val_accuracy: 0.6382
# Epoch 64/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8250 - accuracy: 0.7296 - val_loss: 1.1045 - val_accuracy: 0.6420
# Epoch 65/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8263 - accuracy: 0.7302 - val_loss: 1.1629 - val_accuracy: 0.6293
# Epoch 66/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.8209 - accuracy: 0.7336 - val_loss: 1.1226 - val_accuracy: 0.6410
# Epoch 67/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.8151 - accuracy: 0.7267 - val_loss: 1.1724 - val_accuracy: 0.6257
# Epoch 68/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.8197 - accuracy: 0.7291 - val_loss: 1.1301 - val_accuracy: 0.6375
# Epoch 69/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 0.8116 - accuracy: 0.7343 - val_loss: 1.1702 - val_accuracy: 0.6222
# Epoch 70/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.8156 - accuracy: 0.7315 - val_loss: 1.0675 - val_accuracy: 0.6581
# Epoch 71/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.8021 - accuracy: 0.7333 - val_loss: 1.0688 - val_accuracy: 0.6499
# Epoch 72/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7942 - accuracy: 0.7344 - val_loss: 1.1136 - val_accuracy: 0.6392
# Epoch 73/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.7884 - accuracy: 0.7424 - val_loss: 1.1567 - val_accuracy: 0.6324
# Epoch 74/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.7853 - accuracy: 0.7397 - val_loss: 1.0551 - val_accuracy: 0.6589
# Epoch 75/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7813 - accuracy: 0.7388 - val_loss: 1.1014 - val_accuracy: 0.6471
# Epoch 76/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.7822 - accuracy: 0.7394 - val_loss: 1.0870 - val_accuracy: 0.6456
# Epoch 77/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7731 - accuracy: 0.7474 - val_loss: 1.0943 - val_accuracy: 0.6464
# Epoch 78/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.7736 - accuracy: 0.7454 - val_loss: 1.1224 - val_accuracy: 0.6438
# Epoch 79/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7611 - accuracy: 0.7480 - val_loss: 1.1307 - val_accuracy: 0.6375
# Epoch 80/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7669 - accuracy: 0.7431 - val_loss: 1.0826 - val_accuracy: 0.6548
# Epoch 81/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.7604 - accuracy: 0.7495 - val_loss: 1.0586 - val_accuracy: 0.6647
# Epoch 82/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7669 - accuracy: 0.7490 - val_loss: 1.2365 - val_accuracy: 0.6079
# Epoch 83/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.7586 - accuracy: 0.7516 - val_loss: 1.0905 - val_accuracy: 0.6512
# Epoch 84/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.7435 - accuracy: 0.7539 - val_loss: 1.0968 - val_accuracy: 0.6489
# Epoch 85/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.7467 - accuracy: 0.7577 - val_loss: 1.2563 - val_accuracy: 0.6099
# Epoch 86/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7522 - accuracy: 0.7553 - val_loss: 1.0991 - val_accuracy: 0.6535
# Epoch 87/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7479 - accuracy: 0.7522 - val_loss: 1.1930 - val_accuracy: 0.6257
# Epoch 88/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.7429 - accuracy: 0.7535 - val_loss: 1.1080 - val_accuracy: 0.6423
# Epoch 89/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.7347 - accuracy: 0.7546 - val_loss: 1.0882 - val_accuracy: 0.6578
# Epoch 90/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.7274 - accuracy: 0.7605 - val_loss: 1.1276 - val_accuracy: 0.6436
# Epoch 91/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 0.7219 - accuracy: 0.7626 - val_loss: 1.2076 - val_accuracy: 0.6201
# Epoch 92/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.7306 - accuracy: 0.7636 - val_loss: 1.1588 - val_accuracy: 0.6336
# Epoch 93/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 0.7261 - accuracy: 0.7600 - val_loss: 1.0604 - val_accuracy: 0.6606
# Epoch 94/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.7214 - accuracy: 0.7642 - val_loss: 1.1145 - val_accuracy: 0.6484
# Epoch 95/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.7335 - accuracy: 0.7572 - val_loss: 1.1567 - val_accuracy: 0.6341
# Epoch 96/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7205 - accuracy: 0.7668 - val_loss: 1.1693 - val_accuracy: 0.6306
# Epoch 97/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.7117 - accuracy: 0.7661 - val_loss: 1.1054 - val_accuracy: 0.6510
# Epoch 98/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.7112 - accuracy: 0.7646 - val_loss: 1.1176 - val_accuracy: 0.6448
# Epoch 99/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.7097 - accuracy: 0.7708 - val_loss: 1.2000 - val_accuracy: 0.6206
# Epoch 100/2000
# 74/74 [==============================] - 28s 380ms/step - loss: 0.7099 - accuracy: 0.7664 - val_loss: 1.0081 - val_accuracy: 0.6785
# Epoch 101/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6950 - accuracy: 0.7680 - val_loss: 1.0593 - val_accuracy: 0.6688
# Epoch 102/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.6977 - accuracy: 0.7720 - val_loss: 1.0961 - val_accuracy: 0.6527
# Epoch 103/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.7026 - accuracy: 0.7706 - val_loss: 1.1422 - val_accuracy: 0.6372
# Epoch 104/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.7024 - accuracy: 0.7660 - val_loss: 1.1392 - val_accuracy: 0.6392
# Epoch 105/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.6919 - accuracy: 0.7703 - val_loss: 1.1423 - val_accuracy: 0.6413
# Epoch 106/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6836 - accuracy: 0.7758 - val_loss: 1.1463 - val_accuracy: 0.6364
# Epoch 107/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.6824 - accuracy: 0.7767 - val_loss: 1.0464 - val_accuracy: 0.6675
# Epoch 108/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.6855 - accuracy: 0.7706 - val_loss: 1.1226 - val_accuracy: 0.6403
# Epoch 109/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.6759 - accuracy: 0.7784 - val_loss: 1.0410 - val_accuracy: 0.6724
# Epoch 110/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.6767 - accuracy: 0.7766 - val_loss: 1.1641 - val_accuracy: 0.6397
# Epoch 111/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.6705 - accuracy: 0.7802 - val_loss: 1.0628 - val_accuracy: 0.6611
# Epoch 112/2000
# 74/74 [==============================] - 30s 401ms/step - loss: 0.6736 - accuracy: 0.7792 - val_loss: 1.1629 - val_accuracy: 0.6346
# Epoch 113/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6733 - accuracy: 0.7791 - val_loss: 1.0761 - val_accuracy: 0.6566
# Epoch 114/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.6611 - accuracy: 0.7814 - val_loss: 1.1032 - val_accuracy: 0.6563
# Epoch 115/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6654 - accuracy: 0.7788 - val_loss: 1.0660 - val_accuracy: 0.6545
# Epoch 116/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6726 - accuracy: 0.7774 - val_loss: 1.1744 - val_accuracy: 0.6390
# Epoch 117/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6602 - accuracy: 0.7812 - val_loss: 1.2008 - val_accuracy: 0.6265
# Epoch 118/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6652 - accuracy: 0.7835 - val_loss: 1.1071 - val_accuracy: 0.6525
# Epoch 119/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6512 - accuracy: 0.7853 - val_loss: 1.0743 - val_accuracy: 0.6543
# Epoch 120/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6514 - accuracy: 0.7834 - val_loss: 1.1378 - val_accuracy: 0.6448
# Epoch 121/2000
# 74/74 [==============================] - 28s 381ms/step - loss: 0.6514 - accuracy: 0.7886 - val_loss: 1.1031 - val_accuracy: 0.6520
# Epoch 122/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.6440 - accuracy: 0.7835 - val_loss: 1.1462 - val_accuracy: 0.6484
# Epoch 123/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.6396 - accuracy: 0.7874 - val_loss: 1.0845 - val_accuracy: 0.6601
# Epoch 124/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.6479 - accuracy: 0.7846 - val_loss: 1.0609 - val_accuracy: 0.6662
# Epoch 125/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.6339 - accuracy: 0.7893 - val_loss: 1.0956 - val_accuracy: 0.6624
# Epoch 126/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6431 - accuracy: 0.7874 - val_loss: 1.0980 - val_accuracy: 0.6611
# Epoch 127/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.6298 - accuracy: 0.7901 - val_loss: 1.2076 - val_accuracy: 0.6283
# Epoch 128/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6346 - accuracy: 0.7899 - val_loss: 1.1143 - val_accuracy: 0.6543
# Epoch 129/2000
# 74/74 [==============================] - 29s 391ms/step - loss: 0.6279 - accuracy: 0.7922 - val_loss: 1.0517 - val_accuracy: 0.6718
# Epoch 130/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.6318 - accuracy: 0.7934 - val_loss: 1.1103 - val_accuracy: 0.6583
# Epoch 131/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.6282 - accuracy: 0.7871 - val_loss: 1.0628 - val_accuracy: 0.6678
# Epoch 132/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6339 - accuracy: 0.7902 - val_loss: 1.1608 - val_accuracy: 0.6446
# Epoch 133/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.6194 - accuracy: 0.7975 - val_loss: 1.1117 - val_accuracy: 0.6525
# Epoch 134/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.6311 - accuracy: 0.7933 - val_loss: 1.0695 - val_accuracy: 0.6642
# Epoch 135/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.6259 - accuracy: 0.7970 - val_loss: 1.0814 - val_accuracy: 0.6650
# Epoch 136/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6169 - accuracy: 0.7903 - val_loss: 1.0367 - val_accuracy: 0.6744
# Epoch 137/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.6074 - accuracy: 0.7991 - val_loss: 1.1280 - val_accuracy: 0.6484
# Epoch 138/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6250 - accuracy: 0.7927 - val_loss: 0.9644 - val_accuracy: 0.6963
# Epoch 139/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6153 - accuracy: 0.7918 - val_loss: 1.2018 - val_accuracy: 0.6352
# Epoch 140/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.6138 - accuracy: 0.8006 - val_loss: 1.1439 - val_accuracy: 0.6471
# Epoch 141/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.6066 - accuracy: 0.7991 - val_loss: 1.1322 - val_accuracy: 0.6550
# Epoch 142/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.6139 - accuracy: 0.7967 - val_loss: 1.1471 - val_accuracy: 0.6525
# Epoch 143/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5995 - accuracy: 0.8014 - val_loss: 1.0907 - val_accuracy: 0.6647
# Epoch 144/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.5970 - accuracy: 0.7999 - val_loss: 1.0463 - val_accuracy: 0.6787
# Epoch 145/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.6041 - accuracy: 0.7950 - val_loss: 1.0780 - val_accuracy: 0.6647
# Epoch 146/2000
# 74/74 [==============================] - 28s 382ms/step - loss: 0.5972 - accuracy: 0.7979 - val_loss: 1.0866 - val_accuracy: 0.6568
# Epoch 147/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.5832 - accuracy: 0.8080 - val_loss: 1.0292 - val_accuracy: 0.6818
# Epoch 148/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.5917 - accuracy: 0.8039 - val_loss: 1.2152 - val_accuracy: 0.6301
# Epoch 149/2000
# 74/74 [==============================] - 29s 392ms/step - loss: 0.5919 - accuracy: 0.8018 - val_loss: 1.1011 - val_accuracy: 0.6657
# Epoch 150/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.5916 - accuracy: 0.8042 - val_loss: 1.1878 - val_accuracy: 0.6420
# Epoch 151/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.5876 - accuracy: 0.8020 - val_loss: 1.0383 - val_accuracy: 0.6734
# Epoch 152/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5784 - accuracy: 0.8072 - val_loss: 1.1786 - val_accuracy: 0.6512
# Epoch 153/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5902 - accuracy: 0.8081 - val_loss: 1.1637 - val_accuracy: 0.6489
# Epoch 154/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.5803 - accuracy: 0.8096 - val_loss: 1.0046 - val_accuracy: 0.6910
# Epoch 155/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5922 - accuracy: 0.8024 - val_loss: 1.0612 - val_accuracy: 0.6741
# Epoch 156/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.5852 - accuracy: 0.8040 - val_loss: 1.1341 - val_accuracy: 0.6550
# Epoch 157/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.5788 - accuracy: 0.8084 - val_loss: 1.0674 - val_accuracy: 0.6678
# Epoch 158/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5685 - accuracy: 0.8166 - val_loss: 1.0151 - val_accuracy: 0.6922
# Epoch 159/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5772 - accuracy: 0.8082 - val_loss: 1.0546 - val_accuracy: 0.6772
# Epoch 160/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.5732 - accuracy: 0.8078 - val_loss: 1.0316 - val_accuracy: 0.6820
# Epoch 161/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.5753 - accuracy: 0.8084 - val_loss: 1.2612 - val_accuracy: 0.6242
# Epoch 162/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5632 - accuracy: 0.8146 - val_loss: 1.1524 - val_accuracy: 0.6487
# Epoch 163/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.5748 - accuracy: 0.8073 - val_loss: 1.1816 - val_accuracy: 0.6448
# Epoch 164/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5673 - accuracy: 0.8109 - val_loss: 1.1393 - val_accuracy: 0.6571
# Epoch 165/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5749 - accuracy: 0.8076 - val_loss: 1.1667 - val_accuracy: 0.6482
# Epoch 166/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.5629 - accuracy: 0.8159 - val_loss: 1.0251 - val_accuracy: 0.6861
# Epoch 167/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5582 - accuracy: 0.8193 - val_loss: 1.1079 - val_accuracy: 0.6573
# Epoch 168/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5624 - accuracy: 0.8096 - val_loss: 1.0549 - val_accuracy: 0.6762
# Epoch 169/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5561 - accuracy: 0.8118 - val_loss: 1.0919 - val_accuracy: 0.6688
# Epoch 170/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5610 - accuracy: 0.8142 - val_loss: 1.0870 - val_accuracy: 0.6721
# Epoch 171/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5575 - accuracy: 0.8139 - val_loss: 1.0185 - val_accuracy: 0.6892
# Epoch 172/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5513 - accuracy: 0.8203 - val_loss: 1.0325 - val_accuracy: 0.6851
# Epoch 173/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5650 - accuracy: 0.8078 - val_loss: 0.9931 - val_accuracy: 0.6986
# Epoch 174/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5502 - accuracy: 0.8153 - val_loss: 1.0652 - val_accuracy: 0.6772
# Epoch 175/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.5427 - accuracy: 0.8182 - val_loss: 1.0823 - val_accuracy: 0.6746
# Epoch 176/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.5448 - accuracy: 0.8216 - val_loss: 1.1821 - val_accuracy: 0.6456
# Epoch 177/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5488 - accuracy: 0.8170 - val_loss: 1.2333 - val_accuracy: 0.6359
# Epoch 178/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.5433 - accuracy: 0.8195 - val_loss: 1.0807 - val_accuracy: 0.6708
# Epoch 179/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.5429 - accuracy: 0.8206 - val_loss: 1.0347 - val_accuracy: 0.6810
# Epoch 180/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5392 - accuracy: 0.8218 - val_loss: 1.1320 - val_accuracy: 0.6596
# Epoch 181/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.5474 - accuracy: 0.8166 - val_loss: 0.9812 - val_accuracy: 0.7009
# Epoch 182/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5325 - accuracy: 0.8234 - val_loss: 1.0886 - val_accuracy: 0.6670
# Epoch 183/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5367 - accuracy: 0.8224 - val_loss: 1.1811 - val_accuracy: 0.6515
# Epoch 184/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5314 - accuracy: 0.8229 - val_loss: 1.1126 - val_accuracy: 0.6624
# Epoch 185/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5348 - accuracy: 0.8219 - val_loss: 1.0418 - val_accuracy: 0.6864
# Epoch 186/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.5353 - accuracy: 0.8206 - val_loss: 1.1292 - val_accuracy: 0.6736
# Epoch 187/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.5323 - accuracy: 0.8216 - val_loss: 1.1448 - val_accuracy: 0.6611
# Epoch 188/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5328 - accuracy: 0.8272 - val_loss: 1.1923 - val_accuracy: 0.6515
# Epoch 189/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.5323 - accuracy: 0.8197 - val_loss: 1.1038 - val_accuracy: 0.6629
# Epoch 190/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.5278 - accuracy: 0.8260 - val_loss: 1.1127 - val_accuracy: 0.6652
# Epoch 191/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.5196 - accuracy: 0.8212 - val_loss: 1.1767 - val_accuracy: 0.6535
# Epoch 192/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.5266 - accuracy: 0.8208 - val_loss: 1.0376 - val_accuracy: 0.6894
# Epoch 193/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5229 - accuracy: 0.8250 - val_loss: 1.0750 - val_accuracy: 0.6780
# Epoch 194/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5238 - accuracy: 0.8237 - val_loss: 1.1055 - val_accuracy: 0.6670
# Epoch 195/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.5235 - accuracy: 0.8245 - val_loss: 1.1628 - val_accuracy: 0.6624
# Epoch 196/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5146 - accuracy: 0.8286 - val_loss: 1.1817 - val_accuracy: 0.6591
# Epoch 197/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5203 - accuracy: 0.8274 - val_loss: 1.0977 - val_accuracy: 0.6660
# Epoch 198/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.5187 - accuracy: 0.8292 - val_loss: 1.0934 - val_accuracy: 0.6693
# Epoch 199/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.5162 - accuracy: 0.8270 - val_loss: 1.0774 - val_accuracy: 0.6803
# Epoch 200/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5213 - accuracy: 0.8278 - val_loss: 1.0612 - val_accuracy: 0.6825
# Epoch 201/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.5192 - accuracy: 0.8267 - val_loss: 1.2030 - val_accuracy: 0.6497
# Epoch 202/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.5118 - accuracy: 0.8279 - val_loss: 0.9821 - val_accuracy: 0.7024
# Epoch 203/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.5091 - accuracy: 0.8308 - val_loss: 1.0118 - val_accuracy: 0.6930
# Epoch 204/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.5120 - accuracy: 0.8282 - val_loss: 1.0877 - val_accuracy: 0.6787
# Epoch 205/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4978 - accuracy: 0.8299 - val_loss: 1.1807 - val_accuracy: 0.6581
# Epoch 206/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.5044 - accuracy: 0.8305 - val_loss: 1.2888 - val_accuracy: 0.6321
# Epoch 207/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.5056 - accuracy: 0.8328 - val_loss: 1.1847 - val_accuracy: 0.6545
# Epoch 208/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.5097 - accuracy: 0.8309 - val_loss: 1.1098 - val_accuracy: 0.6683
# Epoch 209/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.5077 - accuracy: 0.8275 - val_loss: 1.0242 - val_accuracy: 0.6912
# Epoch 210/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.5003 - accuracy: 0.8322 - val_loss: 1.0384 - val_accuracy: 0.6932
# Epoch 211/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4918 - accuracy: 0.8356 - val_loss: 0.9858 - val_accuracy: 0.6991
# Epoch 212/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.4997 - accuracy: 0.8350 - val_loss: 1.0945 - val_accuracy: 0.6777
# Epoch 213/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.4967 - accuracy: 0.8339 - val_loss: 1.1670 - val_accuracy: 0.6530
# Epoch 214/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4994 - accuracy: 0.8350 - val_loss: 1.0932 - val_accuracy: 0.6790
# Epoch 215/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.4972 - accuracy: 0.8335 - val_loss: 1.1059 - val_accuracy: 0.6734
# Epoch 216/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4959 - accuracy: 0.8357 - val_loss: 1.1750 - val_accuracy: 0.6571
# Epoch 217/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4876 - accuracy: 0.8389 - val_loss: 1.2795 - val_accuracy: 0.6377
# Epoch 218/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4852 - accuracy: 0.8408 - val_loss: 1.1131 - val_accuracy: 0.6703
# Epoch 219/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4861 - accuracy: 0.8397 - val_loss: 1.1533 - val_accuracy: 0.6599
# Epoch 220/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.4789 - accuracy: 0.8369 - val_loss: 1.0059 - val_accuracy: 0.6943
# Epoch 221/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4876 - accuracy: 0.8345 - val_loss: 1.1235 - val_accuracy: 0.6736
# Epoch 222/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4843 - accuracy: 0.8377 - val_loss: 1.1007 - val_accuracy: 0.6711
# Epoch 223/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4794 - accuracy: 0.8377 - val_loss: 1.0426 - val_accuracy: 0.6922
# Epoch 224/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4864 - accuracy: 0.8395 - val_loss: 1.2208 - val_accuracy: 0.6487
# Epoch 225/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4776 - accuracy: 0.8425 - val_loss: 1.1631 - val_accuracy: 0.6583
# Epoch 226/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4760 - accuracy: 0.8404 - val_loss: 1.0187 - val_accuracy: 0.7011
# Epoch 227/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4797 - accuracy: 0.8376 - val_loss: 1.2939 - val_accuracy: 0.6331
# Epoch 228/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4785 - accuracy: 0.8393 - val_loss: 1.1488 - val_accuracy: 0.6652
# Epoch 229/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.4804 - accuracy: 0.8354 - val_loss: 1.1962 - val_accuracy: 0.6619
# Epoch 230/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4744 - accuracy: 0.8387 - val_loss: 1.1348 - val_accuracy: 0.6797
# Epoch 231/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4698 - accuracy: 0.8436 - val_loss: 1.2516 - val_accuracy: 0.6418
# Epoch 232/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4721 - accuracy: 0.8430 - val_loss: 1.0806 - val_accuracy: 0.6754
# Epoch 233/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4756 - accuracy: 0.8403 - val_loss: 1.2284 - val_accuracy: 0.6530
# Epoch 234/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4678 - accuracy: 0.8386 - val_loss: 1.1527 - val_accuracy: 0.6729
# Epoch 235/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4740 - accuracy: 0.8410 - val_loss: 1.0387 - val_accuracy: 0.6930
# Epoch 236/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4718 - accuracy: 0.8447 - val_loss: 1.1483 - val_accuracy: 0.6752
# Epoch 237/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4756 - accuracy: 0.8416 - val_loss: 1.1718 - val_accuracy: 0.6647
# Epoch 238/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.4661 - accuracy: 0.8405 - val_loss: 0.9758 - val_accuracy: 0.7088
# Epoch 239/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4663 - accuracy: 0.8451 - val_loss: 1.1532 - val_accuracy: 0.6690
# Epoch 240/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4669 - accuracy: 0.8408 - val_loss: 1.0546 - val_accuracy: 0.6851
# Epoch 241/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4635 - accuracy: 0.8480 - val_loss: 1.0723 - val_accuracy: 0.6859
# Epoch 242/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4578 - accuracy: 0.8472 - val_loss: 1.0922 - val_accuracy: 0.6889
# Epoch 243/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4676 - accuracy: 0.8429 - val_loss: 1.0223 - val_accuracy: 0.7014
# Epoch 244/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4608 - accuracy: 0.8466 - val_loss: 1.1256 - val_accuracy: 0.6785
# Epoch 245/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4663 - accuracy: 0.8414 - val_loss: 1.1037 - val_accuracy: 0.6797
# Epoch 246/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.4543 - accuracy: 0.8481 - val_loss: 1.1112 - val_accuracy: 0.6775
# Epoch 247/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4533 - accuracy: 0.8485 - val_loss: 1.1104 - val_accuracy: 0.6736
# Epoch 248/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.4527 - accuracy: 0.8487 - val_loss: 1.1644 - val_accuracy: 0.6645
# Epoch 249/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4564 - accuracy: 0.8444 - val_loss: 1.0132 - val_accuracy: 0.7080
# Epoch 250/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4460 - accuracy: 0.8536 - val_loss: 1.1926 - val_accuracy: 0.6581
# Epoch 251/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.4455 - accuracy: 0.8518 - val_loss: 1.0486 - val_accuracy: 0.6930
# Epoch 252/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4514 - accuracy: 0.8453 - val_loss: 1.0431 - val_accuracy: 0.6904
# Epoch 253/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4490 - accuracy: 0.8478 - val_loss: 1.0671 - val_accuracy: 0.6912
# Epoch 254/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4513 - accuracy: 0.8506 - val_loss: 1.0637 - val_accuracy: 0.6869
# Epoch 255/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.4475 - accuracy: 0.8479 - val_loss: 1.1176 - val_accuracy: 0.6800
# Epoch 256/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4473 - accuracy: 0.8532 - val_loss: 1.2093 - val_accuracy: 0.6662
# Epoch 257/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4501 - accuracy: 0.8453 - val_loss: 1.2948 - val_accuracy: 0.6484
# Epoch 258/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4436 - accuracy: 0.8510 - val_loss: 1.1891 - val_accuracy: 0.6543
# Epoch 259/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4400 - accuracy: 0.8495 - val_loss: 1.1392 - val_accuracy: 0.6746
# Epoch 260/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.4509 - accuracy: 0.8466 - val_loss: 1.1593 - val_accuracy: 0.6698
# Epoch 261/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4385 - accuracy: 0.8534 - val_loss: 1.1557 - val_accuracy: 0.6752
# Epoch 262/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4493 - accuracy: 0.8452 - val_loss: 1.2215 - val_accuracy: 0.6611
# Epoch 263/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4356 - accuracy: 0.8539 - val_loss: 1.1443 - val_accuracy: 0.6718
# Epoch 264/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4427 - accuracy: 0.8512 - val_loss: 1.1688 - val_accuracy: 0.6698
# Epoch 265/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4431 - accuracy: 0.8498 - val_loss: 1.1698 - val_accuracy: 0.6767
# Epoch 266/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4403 - accuracy: 0.8506 - val_loss: 1.0913 - val_accuracy: 0.6904
# Epoch 267/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4373 - accuracy: 0.8507 - val_loss: 1.0529 - val_accuracy: 0.6869
# Epoch 268/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4276 - accuracy: 0.8561 - val_loss: 1.0021 - val_accuracy: 0.7050
# Epoch 269/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4427 - accuracy: 0.8518 - val_loss: 1.0480 - val_accuracy: 0.7022
# Epoch 270/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.4334 - accuracy: 0.8552 - val_loss: 1.0533 - val_accuracy: 0.6976
# Epoch 271/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4271 - accuracy: 0.8528 - val_loss: 1.2526 - val_accuracy: 0.6522
# Epoch 272/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4292 - accuracy: 0.8558 - val_loss: 1.1260 - val_accuracy: 0.6767
# Epoch 273/2000
# 74/74 [==============================] - 28s 383ms/step - loss: 0.4353 - accuracy: 0.8551 - val_loss: 1.1230 - val_accuracy: 0.6808
# Epoch 274/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4312 - accuracy: 0.8583 - val_loss: 1.1093 - val_accuracy: 0.6828
# Epoch 275/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4279 - accuracy: 0.8532 - val_loss: 1.2184 - val_accuracy: 0.6627
# Epoch 276/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4304 - accuracy: 0.8557 - val_loss: 1.0553 - val_accuracy: 0.6940
# Epoch 277/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4359 - accuracy: 0.8567 - val_loss: 1.1731 - val_accuracy: 0.6680
# Epoch 278/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4277 - accuracy: 0.8542 - val_loss: 1.1376 - val_accuracy: 0.6757
# Epoch 279/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4268 - accuracy: 0.8575 - val_loss: 0.9895 - val_accuracy: 0.7131
# Epoch 280/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4269 - accuracy: 0.8531 - val_loss: 1.0756 - val_accuracy: 0.6930
# Epoch 281/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4157 - accuracy: 0.8592 - val_loss: 1.0890 - val_accuracy: 0.6785
# Epoch 282/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4272 - accuracy: 0.8561 - val_loss: 1.1756 - val_accuracy: 0.6713
# Epoch 283/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.4247 - accuracy: 0.8582 - val_loss: 1.1308 - val_accuracy: 0.6797
# Epoch 284/2000
# 74/74 [==============================] - 29s 392ms/step - loss: 0.4274 - accuracy: 0.8549 - val_loss: 1.1230 - val_accuracy: 0.6841
# Epoch 285/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4172 - accuracy: 0.8612 - val_loss: 1.1182 - val_accuracy: 0.6935
# Epoch 286/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4228 - accuracy: 0.8561 - val_loss: 1.1071 - val_accuracy: 0.6861
# Epoch 287/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.4199 - accuracy: 0.8552 - val_loss: 1.1579 - val_accuracy: 0.6752
# Epoch 288/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4121 - accuracy: 0.8561 - val_loss: 1.1662 - val_accuracy: 0.6752
# Epoch 289/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4223 - accuracy: 0.8556 - val_loss: 1.1045 - val_accuracy: 0.6871
# Epoch 290/2000
# 74/74 [==============================] - 29s 392ms/step - loss: 0.4136 - accuracy: 0.8617 - val_loss: 1.1025 - val_accuracy: 0.6871
# Epoch 291/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4173 - accuracy: 0.8589 - val_loss: 1.2958 - val_accuracy: 0.6476
# Epoch 292/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4162 - accuracy: 0.8566 - val_loss: 1.0809 - val_accuracy: 0.6976
# Epoch 293/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4226 - accuracy: 0.8586 - val_loss: 1.1176 - val_accuracy: 0.6818
# Epoch 294/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.4194 - accuracy: 0.8589 - val_loss: 1.0544 - val_accuracy: 0.7034
# Epoch 295/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4154 - accuracy: 0.8584 - val_loss: 1.0909 - val_accuracy: 0.6846
# Epoch 296/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4146 - accuracy: 0.8609 - val_loss: 1.2254 - val_accuracy: 0.6619
# Epoch 297/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4126 - accuracy: 0.8583 - val_loss: 1.0010 - val_accuracy: 0.7111
# Epoch 298/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4142 - accuracy: 0.8599 - val_loss: 1.0699 - val_accuracy: 0.6920
# Epoch 299/2000
# 74/74 [==============================] - 29s 391ms/step - loss: 0.4093 - accuracy: 0.8575 - val_loss: 1.1071 - val_accuracy: 0.6803
# Epoch 300/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4019 - accuracy: 0.8650 - val_loss: 1.1415 - val_accuracy: 0.6813
# Epoch 301/2000
# 74/74 [==============================] - 29s 385ms/step - loss: 0.4073 - accuracy: 0.8608 - val_loss: 1.1262 - val_accuracy: 0.6848
# Epoch 302/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4078 - accuracy: 0.8590 - val_loss: 1.1048 - val_accuracy: 0.6950
# Epoch 303/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4020 - accuracy: 0.8644 - val_loss: 1.1462 - val_accuracy: 0.6780
# Epoch 304/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.4062 - accuracy: 0.8626 - val_loss: 1.1084 - val_accuracy: 0.6904
# Epoch 305/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.3982 - accuracy: 0.8636 - val_loss: 1.2132 - val_accuracy: 0.6657
# Epoch 306/2000
# 74/74 [==============================] - 29s 392ms/step - loss: 0.4033 - accuracy: 0.8625 - val_loss: 1.3267 - val_accuracy: 0.6471
# Epoch 307/2000
# 74/74 [==============================] - 28s 384ms/step - loss: 0.4018 - accuracy: 0.8650 - val_loss: 1.2652 - val_accuracy: 0.6576
# Epoch 308/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.4009 - accuracy: 0.8628 - val_loss: 1.1637 - val_accuracy: 0.6800
# Epoch 309/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.3956 - accuracy: 0.8621 - val_loss: 1.0527 - val_accuracy: 0.6968
# Epoch 310/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4044 - accuracy: 0.8588 - val_loss: 1.0802 - val_accuracy: 0.6953
# Epoch 311/2000
# 74/74 [==============================] - 29s 393ms/step - loss: 0.4115 - accuracy: 0.8588 - val_loss: 1.1765 - val_accuracy: 0.6782
# Epoch 312/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4008 - accuracy: 0.8622 - val_loss: 1.1085 - val_accuracy: 0.6915
# Epoch 313/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.3953 - accuracy: 0.8641 - val_loss: 1.1107 - val_accuracy: 0.6831
# Epoch 314/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.3982 - accuracy: 0.8669 - val_loss: 1.0857 - val_accuracy: 0.6920
# Epoch 315/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4050 - accuracy: 0.8630 - val_loss: 1.1847 - val_accuracy: 0.6693
# Epoch 316/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.3960 - accuracy: 0.8627 - val_loss: 1.0699 - val_accuracy: 0.6986
# Epoch 317/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.4039 - accuracy: 0.8606 - val_loss: 1.0741 - val_accuracy: 0.6963
# Epoch 318/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.4082 - accuracy: 0.8596 - val_loss: 1.2313 - val_accuracy: 0.6721
# Epoch 319/2000
# 74/74 [==============================] - 29s 391ms/step - loss: 0.3839 - accuracy: 0.8703 - val_loss: 1.1669 - val_accuracy: 0.6772
# Epoch 320/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.3889 - accuracy: 0.8695 - val_loss: 1.0792 - val_accuracy: 0.6945
# Epoch 321/2000
# 74/74 [==============================] - 29s 391ms/step - loss: 0.4033 - accuracy: 0.8634 - val_loss: 1.1001 - val_accuracy: 0.6910
# Epoch 322/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.3879 - accuracy: 0.8717 - val_loss: 1.1433 - val_accuracy: 0.6823
# Epoch 323/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.3868 - accuracy: 0.8674 - val_loss: 1.1350 - val_accuracy: 0.6782
# Epoch 324/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.3899 - accuracy: 0.8692 - val_loss: 1.0264 - val_accuracy: 0.7085
# Epoch 325/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.3786 - accuracy: 0.8743 - val_loss: 1.1279 - val_accuracy: 0.6866
# Epoch 326/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.3863 - accuracy: 0.8714 - val_loss: 1.2196 - val_accuracy: 0.6708
# Epoch 327/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.3934 - accuracy: 0.8658 - val_loss: 1.1328 - val_accuracy: 0.6887
# Epoch 328/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.3826 - accuracy: 0.8693 - val_loss: 1.0630 - val_accuracy: 0.7001
# Epoch 329/2000
# 74/74 [==============================] - 29s 386ms/step - loss: 0.3905 - accuracy: 0.8678 - val_loss: 1.0958 - val_accuracy: 0.6920
# Epoch 330/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.3918 - accuracy: 0.8660 - val_loss: 1.1030 - val_accuracy: 0.6851
# Epoch 331/2000
# 74/74 [==============================] - 29s 391ms/step - loss: 0.3892 - accuracy: 0.8689 - val_loss: 1.1338 - val_accuracy: 0.6792
# Epoch 332/2000
# 74/74 [==============================] - 29s 387ms/step - loss: 0.3837 - accuracy: 0.8682 - val_loss: 1.3129 - val_accuracy: 0.6461
# Epoch 333/2000
# 74/74 [==============================] - 29s 388ms/step - loss: 0.3887 - accuracy: 0.8684 - val_loss: 1.2768 - val_accuracy: 0.6550
# Epoch 334/2000
# 74/74 [==============================] - 29s 390ms/step - loss: 0.3850 - accuracy: 0.8714 - val_loss: 1.1259 - val_accuracy: 0.6887
# Epoch 335/2000
# 74/74 [==============================] - 29s 392ms/step - loss: 0.3939 - accuracy: 0.8656 - val_loss: 1.1439 - val_accuracy: 0.6808
# Epoch 336/2000
# 74/74 [==============================] - 29s 393ms/step - loss: 0.3824 - accuracy: 0.8724 - val_loss: 1.1212 - val_accuracy: 0.6828
# Epoch 337/2000
# 74/74 [==============================] - 28s 385ms/step - loss: 0.3755 - accuracy: 0.8686 - val_loss: 1.1137 - val_accuracy: 0.6902
# Epoch 338/2000
# 74/74 [==============================] - 29s 389ms/step - loss: 0.3805 - accuracy: 0.8749 - val_loss: 1.1202 - val_accuracy: 0.6864
# Epoch 00338: early stopping

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label = 'test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label = 'test')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='upper right')

# %%
test_acc = model.evaluate(test_batch, verbose=2)
print('Test accuracy: ',test_acc[1]) 
print('Test loss: ',test_acc[0])
# Out:
# 31/31 - 5s - loss: 1.1202 - accuracy: 0.6864 - 5s/epoch - 151ms/step
# Test accuracy:  0.6863694190979004
# Test loss:  1.120245099067688

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(img, cmap=plt.cm.binary)
  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_labels[predicted_label],
                                100*np.max(predictions_array),
                                class_labels[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
labels =[]
labels_hat=[]
for image, label in test_batch:
  y_pred=model.predict(image)
  classes = np.argmax(y_pred,axis = 1)
  labels.extend(list(label.numpy()))
  labels_hat.extend(list(classes))

con_mat = tf.math.confusion_matrix(labels=labels, predictions=labels_hat).numpy()

# %%
import pandas as pd
import seaborn as sns

con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

con_mat_df = pd.DataFrame(con_mat_norm,
                     index = class_labels, 
                     columns = class_labels)

figure = plt.figure(figsize=(10, 10))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
#reference:- https://www.tensorflow.org/tutorials/keras/classification
for test_images, test_labels in test_batch.take(1):  
  for l in range(len(label)):
    predictions = probability_model.predict(test_images)
    i = l
    plt.figure(figsize=(6,3))
    plt.subplot(1,2,1)
    plot_image(i, predictions[i], test_labels, test_images)
    plt.subplot(1,2,2)
    plot_value_array(i, predictions[i],  test_labels)
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
